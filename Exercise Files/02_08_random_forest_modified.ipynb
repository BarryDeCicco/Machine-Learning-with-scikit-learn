# %% [markdown]
# <a href="https://colab.research.google.com/github/BarryDeCicco/Machine-Learning-with-scikit-learn/blob/main/Exercise%20Files/02_08_random_forest_modified.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Modified by Barry DeCicco, 21 July 2026

# %% [markdown]
# # 02_08 — Rapidly build models with Random Forest
#
# In this notebook, you'll see how **Random Forests** improve on single Decision Trees by combining the predictions of many trees trained on slightly different data.
#
# You'll use the same `make_moons` dataset to compare performance and visualize smoother decision boundaries.

# %% [markdown]
# ## Import libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_moons
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Generate the dataset

# %%
X, y = make_moons(n_samples=1000, noise=0.25, random_state=42)

plt.figure(figsize=(5,4))
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.coolwarm, edgecolor='k')
plt.title("make_moons dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# ## Train a Random Forest model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

forest = RandomForestClassifier(n_estimators=50, random_state=1)
forest.fit(X_train, y_train)

y_pred = forest.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.3f}")
# Out:
# Accuracy: 0.940

# %% [markdown]
# ## Examine feature importances

# %%
import pandas as pd

feature_importance = pd.Series(forest.feature_importances_, index=['Feature 1', 'Feature 2'])
feature_importance.plot(kind='bar', color='teal', title='Feature Importance')
plt.ylabel("Importance")
plt.show()

feature_importance
# Out:
# Feature 1    0.447167
# Feature 2    0.552833
# dtype: float64
